# %% [markdown]
# # Import

# %%
import pdb
import spacy
nlp = spacy.load('en_core_web_md')
import re
import copy
from num2words import num2words
from nltk.corpus import stopwords

# %%
stimulus = 'hidden_figures'
stop_words = set(stopwords.words('english'))
stop_words.add('sir')

# %% [markdown]
# # Helper functions

# %% [markdown]
# ## Extract subtitles from .srt file

# %%
def extract_subtitles(subtitles_path):
    subtitles = []
    with open(subtitles_path, 'r') as subtitles_file:
        for line in subtitles_file.readlines():
            line = line.replace('\n','').replace('\t','')
            if line.isdigit():
                subtitles.append("")
            elif "-->" in line or line == "":
                # ignore timestamps
                continue
            elif line[0] == "-":
                if subtitles[-1] == "":
                    del subtitles[-1]
                subtitles.append(line[1:].strip())
            elif subtitles[-1] == "":
                del subtitles[-1]
                subtitles.append(line)
            else:
                subtitles[-1] += " " + line
    return subtitles

# %% [markdown]
# ## Parse Characters & Sentences from (Already Parsed) Screenplay

# %%
def extract_parsed_screenplay_info(characters_path, sentences_path):
    screenplay_chars, screenplay_sents = [], []

    with open(characters_path, 'r') as characters_file:
        with open(sentences_path, 'r') as sentences_file:
            screenplay_chars = [line.strip() for line in characters_file.readlines()]
            screenplay_sents = [line.strip() for line in sentences_file.readlines()]
    return screenplay_chars, screenplay_sents

# %% [markdown]
# ## Match subtitles to screenplay sentences

# %%
def sublist(ps, qs):
    ps_diff = [p for p in ps if p in qs]
    qs_diff = [q for q in qs if q in ps]
    return (ps_diff == ps) or (qs_diff == qs)

def num_to_word(w):
    if w.isdecimal():
        w = num2words(w)
    return w

def format_string(s):
    s = re.sub(r'\.{2,}', ', ', s)
    s = s.lower().replace(',', '').replace('.', '').replace('?', '').replace('!', '').replace("’", '').replace("'",'').replace("-",' ').strip()
    s = ' '.join([num_to_word(w) for w in s.split()])
    return s

def spacy_similarity(s1, s2):
    # Embedding similarity according to embeddings generated from spacy nlp
    emb1, emb2 = nlp(s1), nlp(s2)
    sim = emb1.similarity(emb2)
    return sim

# %%
def find_match(sub, candidates):
    sub = format_string(sub)
    for i, cand in enumerate(candidates):
        candidates[i] = format_string(cand)
    
    # (a) exact match
    if sub in candidates:
        return candidates.index(sub), True
    
    # (b) "one contains another" match
    sub_words = sub.split()
    found_match, match_idx = False, None
    for i, cand in enumerate(candidates):
        if len(cand.split())<2:
            continue
        if sublist(sub_words, cand.split()) :
            found_match, match_idx = True, i
            break
    if found_match:
        return match_idx, False
    
    # (c) similarity score > 0.9 and intersection of word lists 
    # after removing stop words satisfies certain restrictions
    best_score, match_idx = 0., None
    filtered_sub = [w for w in sub_words if not w in stop_words]
    for i, cand in enumerate(candidates):
        if cand == '':
            continue
            
        cand_score = spacy_similarity(sub, cand)
        cand_words = cand.split()
        filtered_cand = [w for w in cand_words if not w in stop_words]
        filtered_intersection = list(set(filtered_sub) & set(filtered_cand))
        
        if best_score<cand_score and ((len(filtered_sub)>=4 and len(filtered_intersection)>=2) \
                                      or (len(filtered_sub)<4 and len(filtered_intersection)>=1)):
            best_score, match_idx = cand_score, i
    return match_idx, False

# %% [markdown]
# ## Save subtitles with character labels

# %%
def get_match_idx(sub, labeled_subs):
    match_idx = None
    for i, (m, lsub) in enumerate(labeled_subs):
        if lsub == sub:
            match_idx = m
            del labeled_subs[i]
            return match_idx, labeled_subs
    print("Found no match in get_match_idx for sub: {}".format(sub))
    raise Exception("This should never happen in get_match_idx")

def rewrite_subtitles_with_characters(scply_chars, labeled_subs, subtitles_path, out_path):
    start_new_line = True
    with open(subtitles_path, 'r') as subtitles_file:
        subtitles_lines = subtitles_file.readlines()
        with open(out_path, 'w+') as out_file:
            for i, line in enumerate(subtitles_lines):
                formatted_line = line.replace('\n','').replace('\t','')
                if formatted_line.isdigit():
                    start_new_line = True
                    out_line = line
                elif "-->" in formatted_line or formatted_line == "":
                    out_line = line
                elif formatted_line[0] == "-":
                    # collect full subtitle that might span multiple lines
                    curr_sub = formatted_line[1:].strip()
                    next_line = subtitles_lines[i+1]
                    fmt_next_line = next_line.replace('\n','').replace('\t','')
                    while fmt_next_line != "" and fmt_next_line[0] != "-":
                        curr_sub += " " + fmt_next_line
                        i += 1
                        next_line = subtitles_lines[i+1]
                        fmt_next_line = next_line.replace('\n','').replace('\t','')
                    # get character
                    match_idx, labeled_subs = get_match_idx(curr_sub, labeled_subs)
                    matched_char = scply_chars[match_idx] if match_idx is not None else "None"
                    out_line = matched_char + ' ' + line
                    start_new_line = False
                elif start_new_line:
                    # collect full subtitle that might span multiple lines
                    curr_sub = formatted_line
                    next_line = subtitles_lines[i+1]
                    fmt_next_line = next_line.replace('\n','').replace('\t','')
                    while fmt_next_line != "" and fmt_next_line[0] != "-":
                        curr_sub += " " + fmt_next_line
                        i += 1
                        next_line = subtitles_lines[i+1]
                        fmt_next_line = next_line.replace('\n','').replace('\t','')
                    # get character
                    match_idx, labeled_subs = get_match_idx(curr_sub, labeled_subs)
                    matched_char = scply_chars[match_idx] if match_idx is not None else "None"
                    out_line = matched_char + ' - ' + line
                    start_new_line = False
                else:
                    out_line = line
                out_file.write(out_line)

# %% [markdown]
# # Testing this code with an example

# %%
subtitles_path = 'subtitles/{}_subtitles.srt'.format(stimulus)
characters_path = 'screenplays/separated_characters_and_dialogues/{}_characters.txt'.format(stimulus)
sentences_path = 'screenplays/separated_characters_and_dialogues/{}_dialogues.txt'.format(stimulus)
out_path = 'subtitles_with_characters/{}_subtitles.txt'.format(stimulus)

# %%
subs = extract_subtitles(subtitles_path)
scply_chars, scply_sents = extract_parsed_screenplay_info(characters_path, sentences_path)

# %%
# After running this cell, labeled_subs contains two-element lists [i, s] where i is either None or the index of a 
# screenplay sentence that matched with the subtitle s.
labeled_subs = []
prev_matched = {}
shift = 15
max_dialogue_stretch = 5 # how far apart two subtitles matching to the same sentence can be

prev_match_idx, prev_pivot = None, 0
for i, sub in enumerate(subs):
    # generate candidates for this sub
    pivot = prev_match_idx if (prev_match_idx is not None) else prev_pivot
    lo = pivot-shift if pivot-shift>=0 else 0
    hi = pivot+shift if pivot+shift<len(scply_sents) else len(scply_sents)
    candidates = scply_sents[lo:hi]
    
    # keep searching for matches until there's nothing left or we find a candidate that satisfies one of:
    # (a) is the exact same as our subtitle
    # (b) one's word list is contained within the other and both have 3 or more words
    # (c) similarity score > 0.9 and intersection of word lists after removing stop words satisfies certain restrictions
    match_rejected = True
    while match_rejected:
        match_idx, exact_match = find_match(sub, candidates)
        if exact_match and len(sub.split())>=3:
            prev_matched[lo+match_idx] = i
            match_rejected = False
        elif (match_idx is not None) and (lo+match_idx) in prev_matched:
            i_prev = prev_matched[lo+match_idx]
            if i_prev+max_dialogue_stretch >= i:
                prev_matched[lo+match_idx] = i
                match_rejected = False # allow relatively close subtitles to be matched to same sentence
            else:
                candidates[match_idx] = ''
        else:
            if match_idx is not None:
                prev_matched[lo+match_idx] = i
            match_rejected = False
    
    # Dense printing here to be able to go over the matches at the end and see if they make sense
    if match_idx is None:
        print("{} -> None".format(sub))
    else:
        print("{} -> {}".format(sub, scply_sents[lo+match_idx]))
        match_idx = lo+match_idx
        
    labeled_subs.append([match_idx, sub])
    prev_match_idx, prev_pivot = match_idx, pivot
# Out:
# Fourteen.. Fifteen.. -> 14, 15, 16...prime.
# Sixteen. Prime. -> 14, 15, 16...prime.
# Eighteen. Prime. -> 18, prime.
# Twenty. -> 20, 21, 22, prime, 24, 25, 26...
# Twenty-one. -> 20, 21, 22, prime, 24, 25, 26...
# Twenty-two. -> 20, 21, 22, prime, 24, 25, 26...
# West Virginia Collegiate Institute is the best school for Negros in the state. -> West Virginia Collegiate Institute is the best school for Negros in the state.
# It's the only school, past the eighth grade, anywhere near here. -> It’s the only school, past the eighth grade, anywhere close to here.
# Isosceles. Scalene -> Isosceles, scalene, obtuse, equilateral, rhombus...
# Equilateral -> Isosceles, scalene, obtuse, equilateral, rhombus...
# Rhombus -> Isosceles, scalene, obtuse, equilateral, rhombus...
# Trapezoid -> Trapezoid, tetrahedron, octahedron, dodecahedron...
# Katherine's in the sixth grade. -> Katherine’s in the sixth grade.
# They want to take her early. -> They want to take her early.
# Tetrahedron, -> Trapezoid, tetrahedron, octahedron, dodecahedron...
# Dodecahedron -> Trapezoid, tetrahedron, octahedron, dodecahedron...
# They're offering a full scholarship. -> They’re offering a full scholarship.
# All you have to do is get there. -> All you have to do is get there.
# Ms. Coleman. -> Ms. Coleman.
# Why don't you solve the equation on the board? -> Why don’t you figure out the equation on the board?
# We took up a collection amongst the teachers and such, -> Joshua, Joylette...we took up a collection amongst the teachers and such, a few parents.
# It's not a lot. -> It’s not a whole lot, but it’ll surely help get you settled in.
# But it's enough to help get you settle down -> It’s not a whole lot, but it’ll surely help get you settled in.
# That's more than kind, Ms. Sumner. -> That’s beyond kind, Ms. Sumner.
# If the product of two terms is zero, -> If the product of two terms is zero, then common sense says at least one of the two terms has to be zero to start with.
# then common sense says at least one of the two terms -> If the product of two terms is zero, then common sense says at least one of the two terms has to be zero to start with.
# has to be zero to start with -> If the product of two terms is zero, then common sense says at least one of the two terms has to be zero to start with.
# So, if you move all the terms over to one side, -> So, if you move all the terms over to one side, you can put the quadratics into a form that can be factored, allowing that side of the equation to equal zero.
# you'd put the quadratics into a form that can be factored, -> So, if you move all the terms over to one side, you can put the quadratics into a form that can be factored, allowing that side of the equation to equal zero.
# Who the hell is he? -> Who the hell is he?
# Paul Stafford. Our Lead Engineer, Mr. Webb. -> Paul Stafford...our Lead Engineer, Mr. Webb.
# I think what he meant to say is that speculation, at least -> I think what he meant to say is that speculation, at least on our side of the equation, can be dangerous.
# on our side of the equation by definition, can be.. -> I think what he meant to say is that speculation, at least on our side of the equation, can be dangerous.
# Just a little dangerous. -> I think what he meant to say is that speculation, at least on our side of the equation, can be dangerous.
# Dangerous? -> I think what he meant to say is that speculation, at least on our side of the equation, can be dangerous.
# You know what's dangerous, Mr. Stafford? -> You know what’s dangerous...inaction.
# Inaction, and indecision. -> Inaction and indecision.
# Russians have a spy satellite lapping the planet, -> The Russians have a spy satellite lapping the planet.
# taking pictures of God knows what! -> Taking pictures of God knows what.
# The President is demanding an immediate response. -> The President is demanding an immediate response.
# No more delays. Alan Shepard, John Glenn, your uncle Bob. -> No more delays.
# Doesn't matter, just get us up there, Harrison -> Doesn’t matter, just get us up there, Harrison.
# We can't justify a space program -> We can’t justify a space program that doesn't put anything in space.
# that doesn't put anything in space. -> We can’t justify a space program that doesn't put anything in space.
# How did that feel in there, Paul? -> How did that feel in there, Paul?
# Do you think you enlightened the Administrator? -> Do you think you enlightened the Administrator?
# No, he didn't look enlightened to me. -> He didn’t look enlightened to me.
# He look enlightened to you, Sam? -> He look enlightened to you, Sam?
# Not particularly. -> Not particularly.
# And just so you know, he's not wrong about what he said in there. -> And just so you know, he’s not wrong about what he said in there.
# You know that, right? -> You know that, right?
# Because now that they can get up there, a bomb will follow. -> Because now that they can get up there, a bomb will follow.
# That's what happens to all our good ideas. -> That’s what happens to all our good ideas.
# I imagine there is too -> None
# Where's the machine? -> Where’s the machine?
# Any day now, Mr. Harrison. -> Any day now, Mr. Harrison.
# Any day now. -> Any day now.
# Yes, sir. -> None
# What's it called? -> What’s it called?
# The initials... -> The initials...the letters
# The IBM. -> IBM.
# International business machine. -> International business machine.
# Space is a business -> Space is business.
# I need a mathematician. -> I need a mathematician.
# I'll put in another request, sir. -> I’ll put in another request, sir.
# Another request. -> Another request.
# Jesus Christ! We don't have a single person, in this entire building, -> Jesus Christ.
# that can handle Analytic Geometry? -> We don’t have a single person, in this entire building, that can handle Analytic Geometry?
# That's what I've been told. -> That’s what I’ve been told.
# Well, tell me something else, Ruth. Like we're going to find such a person -> Well, tell me something else, Ruth.
# before the Russians plant a flag on the damn moon. -> Like we’re going to find such a person, before the Russians plant a flag on the damn moon.
# Ladies, ladies -> None
# If you're tardy, you don't get an assignment -> None
# if you don't get an assignment you don't have a job. -> None
# Eleanor. Data Reduction, Building 202. -> Eleanor you’re with Bernie today in Data Reduction, Building 202.
# Data Reduction? -> Eleanor you’re with Bernie today in Data Reduction, Building 202.
# Well. You're welcome to join the charmers in Magneto-plasmadynamics. -> You’re welcome to join the charmers in Magnetoplasmadynamics.
# Oh! No, ma'am. -> No thank you, ma’am.
# Thank you, Data Reduction's just fine. -> Data Reduction’s just fine.
# Mary. -> Mary.
# Present. -> Present.
# The Mercury 7 prototype has arrived for testing. -> The Mercury 7 prototype has arrived for testing.
# Mr. Zielinski's requesting you. -> Mr. Zielinski’s requesting you...for permanent assignment.
# For permanent assignment. -> Mr. Zielinski’s requesting you...for permanent assignment.
# Are you serious? -> Are you serious?
# Get moving. -> Get moving.
# Oh! Thank you, Jesus! -> Thank you.
# Thank you, Jesus! Oh! Thank you. -> Thank you.
# Mary -> None
# Keep it inside -> Keep it inside, hon.
# I'm sorry, Dor -> Sorry, Dor.
# All right, Mrs. Late -> Mrs. Mitchell.
# You'll also be.. -> None
# Mrs. Mitchell. -> Mrs. Mitchell.
# We're on double time this mornin', girls. -> We’re on double time this mornin’, girls.
# I need these calculations before lunch. -> I need these calculations before lunch.
# The Space Task Group needs a computer, ASAP. -> The Space Task Group needs a computer ASAP.
# Someone with a handle on Analytic Geometry. -> Someone with a handle on Analytic Geometry.
# We can't fill the position outta the East Group. -> Much to my chagrin, we can’t fill the position outta the East Group.
# Permanent or temp? -> Permanent or temp?
# Everything's temporary, Dorothy. -> Everything’s temporary, Dorothy.
# You have someone? -> You have someone?
# Oh! Yes, ma'am. -> Yes, ma’am.
# Katherine's the gal for that. -> Katherine’s the gal for that.
# She can handle any numbers you put in front of her. -> She can handle any numbers you put in front of her.
# I'll check her credentials. -> I’ll check her credentials.
# Didn't think of comin' all the way down here. -> Didn’t think of comin’ all the way down here.
# Here. Pinch press those out. -> None
# Mrs. Mitchell! -> Mrs. Mitchell...if I could-
# If I could. -> Mrs. Mitchell...if I could-
# My application for supervisor, ma'am. -> My application for supervisor, ma’am.
# Was just wondering if they're still considering me for that position. -> Was wondering if they’re still considering me for that position.
# Yes. -> Yes.
# Well, the official word is: no. -> Well, the official word is- no.
# They're not assignin' a permanent supervisor for the Colored Group. -> They’re not assignin’ a permanent supervisor to the Colored Group.
# May I ask why? -> May I ask why?
# I don't know "why." -> I don’t know “why.” I didn’t ask “why.”
# I didn't ask "why." -> I don’t know “why.” I didn’t ask “why.”
# We need a Supervisor, ma'am. -> We need a Supervisor, ma’am.
# We haven't had one since Ms. Jansen got sick It's been almost a year. -> Haven’t had one since Ms. Jansen got sick.
# Things are workin' just fine as is. -> Things are workin’ just fine as is, Dorothy.
# I'm doing the work of a Supervisor. -> I do the work of a Supervisor.
# Well. That's NASA, for ya. -> That’s NASA, for ya.
# Fast with rocket ships. Slow with advancement. -> Fast with rocket ships.
# Get those trajectories calcs worked out. -> Get those trajectories calcs worked out.
# We need em for the Redstone test. -> We need ‘em for the Redstone test.
# Mach 1 tunnel test, T-1 minute. -> Mach 2 tunnel test, T-minus one minute.
# No shoe is worth your life -> No shoe is worth your life.
# One.. One moment! -> Mach 2 tunnel test, T-minus one minute.
# Shut it down. -> None
# If we alter the exterior from smooth -> If we alter the exterior from smooth to corrugated, the capsule would have more stability, despite the air displacement.
# to corrugated, the capsule might have more stability, -> If we alter the exterior from smooth to corrugated, the capsule would have more stability, despite the air displacement.
# But the friction, it's under during reentry.. -> Coupled with rising temperatures on reentry, the contacts soften.
# Most shield erosion occurs -> None
# on the posterior side abutting the retro-boosters. -> None
# Conclusion? -> None
# Well, We're working with a prototype of the capsule, Al. -> We’re working with a prototype of the capsule, Al.
# It's little as one third the size.. -> It’s one third the size-
# I get that. So.. -> Get settled.
# What do you do with our million dollar fan, Karl? -> Well, do we need to turn our million dollar fan down, Karl?
# Turn it down? -> Well, do we need to turn our million dollar fan down, Karl?
# No, I don't think... -> I don’t think-
# Hey! That was a joke. -> That was a joke.
# Paul, if the heat shield comes off -> If the heat shield comes off, what do you think happens to our astronaut?
# what d'you think happens to our astronaut? -> If the heat shield comes off, what do you think happens to our astronaut?
# I know. -> Does she know how to handle Analytic Geometry?
# So we're gonna.. -> None
# We're gonna come up with a solve, right? -> So we’re going to come up with a solve, right?
# Yes, sir. We're working on it. -> Yes, sir.
# Ruth, what's the status on that Computer? -> What’s the status on my Computer?
# She's right behind you, Mr. Harrison. -> She’s right in front of you, Mr. Harrison.
# Does she handle Analytic Geometry? -> Geometry and speaking.
# Absolutely. And she speaks. -> And she speaks.
# Yes, sir. I do. -> Yes, sir.
# Which one? -> Which one?
# Both. -> Both, sir.
# Geometry and speaking. -> Geometry and speaking.
# Ruth. Give me that. -> Then give her the-
# Do you think you.. -> Do you think you can find me the Frenet frame for that data using the GramSchmidt--
# You think you can find me the Frenet frame for this data, -> Do you think you can find me the Frenet frame for that data using the GramSchmidt--
# Using the GramSchmidt... -> Do you think you can find me the Frenet frame for that data using the GramSchmidt--
# With Orthogonalization algorithm. Yes, sir. -> --Orthogonalization algorithm.
# I prefer it over Euclidean coordinates. -> I prefer it over Euclidean coordinates.
# OK. Good. -> Good.
# Good. Then, I'm going to need it by the end of the day. -> Then, I’m going to need it by the end of the day.
# Yes. -> Yes, sir.
# I'm also going to ask you to check Mr. Stafford's math -> And I’m also going to ask you to check Mr. Stafford’s math as well as others on this floor from time to time.
# as well as others on this floor from time to time. -> And I’m also going to ask you to check Mr. Stafford’s math as well as others on this floor from time to time.
# I can.. I can handle that, Al. -> I can work that out myself, Al.
# I'm sure you can, Paul. I'm sure they all can. -> I’m sure you can, Paul.
# But if that were the case, -> But if that were the case, shingles wouldn’t be flying off the heat shield, now would they.
# Shingles wouldn't be flying off the heat shield now, would they? -> But if that were the case, shingles wouldn’t be flying off the heat shield, now would they.
# Excuse me, could I have everyone's attention for a moment? -> Excuse me.
# Thank you. Just a.. -> None
# Just to be clear.. -> I just want to be clear about something...in 14 days the Mercury 7 will be here for training and I have no doubt that they’ll be asking questions about our work.
# In 14 days the Mercury 7 will be here for training. -> I just want to be clear about something...in 14 days the Mercury 7 will be here for training and I have no doubt that they’ll be asking questions about our work.
# And I have no doubt in my mind that they're going to be -> None
# asking us questions about our work. -> I just want to be clear about something...in 14 days the Mercury 7 will be here for training and I have no doubt that they’ll be asking questions about our work.
# I think that's a pretty reason we're giving. We're putting a human.. -> Do I need to remind everyone...that we are putting a human on top of a missile and shooting him into space?
# On top of a missile and shooting him into space -> Do I need to remind everyone...that we are putting a human on top of a missile and shooting him into space?
# And it's never been done before. -> It’s never been done before.
# And because it's never been done. Everything we do -> And because it’s never been done...everything we do between now and then is going to matter- it’s going to matter to their wives, their kids, I believe it’s going to matter to the whole damn country.
# between now and then is going to matter. -> And because it’s never been done...everything we do between now and then is going to matter- it’s going to matter to their wives, their kids, I believe it’s going to matter to the whole damn country.
# It's going to matter to their wives. -> And because it’s never been done...everything we do between now and then is going to matter- it’s going to matter to their wives, their kids, I believe it’s going to matter to the whole damn country.
# To their children. -> None
# I believe it's going to matter to the whole damn country. -> And because it’s never been done...everything we do between now and then is going to matter- it’s going to matter to their wives, their kids, I believe it’s going to matter to the whole damn country.
# So this Space Task Group will be as advertised. -> So this Space Task Group will be as advertised.
# America's greatest engineering and scientific minds -> And Americas greatest engineering and scientific minds will not have a problem with having their work checked.
# are not gonna have a problem -> I’ll double check them, sir, not a problem.
# with having their work checked, are they, Paul? -> And Americas greatest engineering and scientific minds will not have a problem with having their work checked.
# No, sir. -> None
# Good. So let's have an amen, damnit -> So let’s have an amen, goddamnit.
# Amen. -> Amen.
# Amen. -> Amen.
# All right! -> None
# My numbers are spot on. -> My numbers are spot on.
# I'll double check them, sir. No problem. -> None
# I'm not gonna be able to.. -> I’m not going to be able-
# Work on what you can read. -> Work on what you can read.
# The rest is classified. You don't have clearance. -> The rest is classified.
# Excuse me... -> Excuse me...
# May I ask you where the ladies' room is? -> May I ask you where the ladies’ room is?
# Sorry, I have no idea where your bathroom is? -> Sorry, I have no idea where your bathroom is.
# Yes, sir. -> None
# Ah! Yes. -> None
# Ruth! -> None
# Yes, Mr. Harrison. -> Mr. Harrison.
# Where's that girl with the numbers? -> Where’s that girl with those numbers?
# On a... break. -> On a...break.
# We take breaks now? -> We take breaks now.
# My God, where have you been? Are you finished yet? -> My God, where have you been?
# Almost. He said about the end of the day? -> He said- the end of the day?
# The end of the day around here was yesterday. -> The end of the day around here was yesterday.
# I need those done first. -> I want those done first.
# He wants those done first. -> He wants those done first.
# OK! -> None
# Get going. -> Get going.
# Mr. Harrison. -> None
# Oh! Yeah, just set up, you know. -> None
# And Stafford's heat shield calcs? -> And Stafford’s heat shield calcs?
# It's hard to be sure, sir. -> It’s hard to be sure, sir.
# Hard to be sure. -> It’s hard to be sure, sir.
# You know what we're doing here? -> Do you know what we’re doing here?
# Trying to put a man into space, sir. -> We’re trying to put a man in space, sir.
# That's right. -> That’s right.
# That's right. So you can throw that in the trash. -> That’s right.
# Excuse me? -> Excuse me?
# I said you can throw it away -> I said you can throw it away.
# Here. -> Here.
# It's not an insult to your work. It's just.. -> It's not an insult to your work.
# .. Obsolete. That's how fast things are moving around here. -> That's how fast things are moving.
# If I said I was sorry, I'd be saying it all day. -> If I said I was sorry, I'd be saying it all day.
# What I'm asking you to do.. What I'm asking everyone in that room, -> What I’m asking you..what I’m asking everyone one in that room, all my geniuses, is to look beyond the numbers.
# all my... geniuses, is to look beyond the numbers. -> What I’m asking you..what I’m asking everyone one in that room, all my geniuses, is to look beyond the numbers.
# To look around them. -> To look around them.
# Through them. -> Through them.
# For answers to questions we don't even know to ask. -> For answers to questions we don’t even know to ask.
# Math that doesn't yet exist. -> Math that doesn’t yet exist.
# Because without it, we're not going anywhere. -> Because without it, we’re not going anywhere.
# I mean, we're staying on the ground. We're not... -> We’re staying on the ground.
# flying into space. We're not.. -> We’re not flying into space...we’re not circling the earth.
# Circling the earth. And we're certainly not touching the moon. And in my mind.. -> And we’re certainly not touching the moon.
# In my mind, I'm already there. -> And in my mind...I’m already there.
# Are you? -> Are you?
# Yes, sir. -> Yes, sir
# Good. -> Good.
# Because I don't need another smart girl with an adding machine. -> Because I don’t need another smart girl with a calculator.
# Can I go, sir? -> Can I go, sir?
# Go? Yeah. Go, yeah. -> None
# Yes, you can go -> Can I go, sir?
# I'm saying this is so much. I'm not saying that.. I.. -> None
# We've been waiting for hours. -> We’ve been waiting for hours.
# Next time you take the bus. -> Next time you catch a bus.
# She's in a mood. -> She’s in a mood.
# I haven't been late one day in ten years. Haven't been out sick. -> I haven’t been late one day in ten years.
# Haven't complained. My work's on time. It's done right. It's done well. -> Haven’t complained.
# It's not fair, that's a fact. -> It’s not fair, that’s a fact.
# What's not fair is having the responsibility of the Supervisor, -> What’s not fair is having the responsibility of a Supervisor, but not the title or the money.
# but not the title or the pay. -> What’s not fair is having the responsibility of a Supervisor, but not the title or the money.
# Watching you two move on. -> Watching you all get moved on.
# Now don't get me wrong. -> Now don’t get me wrong, any upward movement is movement for us all.
# Any upward movement is movement for us all -> Now don’t get me wrong, any upward movement is movement for us all.
# It just isn't movement for me. -> It just isn’t movement for me.
# Truth be told, Dorothy, I don't really know if I can keep up in that room. -> Truth be told, Dorothy, I don’t know if I can keep up in that room.
# I'll be back with the Computers in a week, -> I’ll be back with the Computers in a week, or out of a job entirely.
# or out of a job entirely. -> I’ll be back with the Computers in a week, or out of a job entirely.
# Oh, please! You're better with the numbers than anyone in the cabin and you know it. -> Oh, please.
# Make that pencil move as fast as your mind does, you'll be fine. -> Make that pencil move as fast as your mind does, you’ll be fine.
# And you. Have some respect! Get your damn feet off my dash board. -> And you.
# This isn't your living room. -> This isn’t your living room.
# I sound like a supervisor, don't I? -> I sound like a supervisor, don’t I?
# A mean, ole salty one. -> A mean, ole salty one.
# Riddled with authority. No question. -> Riddled with authority.
# You don't mess with, Mrs. Vaughan. -> You don’t mess with, Mrs. Vaughan.
# Turn that music up -> None
# Goodnight, Katherine! -> My word, Katherine.
# Bye, Kath! -> None
# Goodnight, ladies! See you in the morning. -> None
# Hey baby -> None
# Hello, mamma. -> None
# I was fixing to call the National Guard. -> I was fixing to call the National Guard.
# Sorry, Momma. -> Sorry, Momma.
# New assignment. -> New assignment.
# Space Task Group. -> The Space Task Group.
# Oh my word, that sounds important -> That sounds important.
# It's a promotion? -> It’s a promotion?
# Might be a slight promotion. -> It’s important and overwhelming...maybe a slight promotion.
# But you want the job, right? -> You want the job, right?
# I think so. -> I think so.
# It's a challenge. But.. -> It’s a challenge.
# Well, it's nothing you can't handle, Katherine. -> Nothing you can’t do, Katherine.
# Thank you, mamma. -> None
# Are they asleep yet? -> None
# They're pretending to be. -> They’re pretending to.
# They're not pretending well enough -> They’re pretending to.
# Thank you, mamma. Love you. -> None
# His faith in us has no limits -> His faith in us has no limit!
# The good Lord.. -> The good Lord has our very own women workin’ on rocket ships!
# Has our very own women.. -> The good Lord has our very own women workin’ on rocket ships!
# Workin' on rocket ships! -> The good Lord has our very own women workin’ on rocket ships!
# And we have National Guardsmen -> And we have National Guardsman defending our freedom!
# defending our freedom -> And we have National Guardsman defending our freedom!
# Give a shout of praise for Colonel Jim Johnson. -> Give a shout of praise for- Colonel Jim Johnson.
# Returning home by the grace of God, -> Returning home by the grace of God, to set up a National Guard unit right here in Hampton!
# to set up a National Guard unit -> Returning home by the grace of God, to set up a National Guard unit right here in Hampton!
# right here in Hampton. -> Returning home by the grace of God, to set up a National Guard unit right here in Hampton!
# Can I get a "Hallelujah" in here?! -> Can I get a “Hallelujah” in here?
# Hallelujah! -> None
# I just don't understand.. I just.. I don't.. -> Understand it.
# I don't understand. -> I don’t want any greens.
# I don't want to talk about this again, OK? -> I don’t want to see you get hurt.
# A female engineer? -> None
# A female engineer. -> None
# We're Negro, baby. Ain't no such thing. Understand it. -> None
# It's not like that there, Levi. -> Probably like that day...and night.
# You can't "apply" for freedom. Freedom is never granted to the oppressed. -> None
# It's got to be demanded. Taken. -> None
# Stop quoting your slogans at me. -> None
# There's more than one way to achieve something. -> None
# I don't want any greens. -> Ladies, I don’t know if I’m-
# I tell you about interrupting? -> She can tell you the rest.
# Here, try this, baby. -> None
# You gonna eat them greens too. -> None
# Kids need to eat their vegetables. -> None
# You'd know that if you was at home. -> Ladies, I don’t know if I’m-
# You better settle down, Levi Jackson. -> None
# Lest you want this female's mind right here, in front of everybody. -> None
# All I'm saying -> Ladies, I don’t know if I’m-
# Don't play the fool. -> Ladies, I don’t know if I’m-
# I don't want to see you get hurt. -> None
# NASA's never ever given you gals your due, -> None
# having a couple of extra degrees ain't gonna change that. -> None
# Civil rights ain't always civil. -> None
# I don't want any greens either. -> None
# No lip, little miss. Your brother gets them, and so do you. -> None
# I hear he's planning on staying in the area. -> None
# Well. That's good for him. -> With three little girls, so well-behaved.
# Katherine, go find your way over there. -> None
# That Colonel Jim is a tall glass of water -> None
# That he is. Tall. Strong. Commanding. -> None
# And I bet he's like that day and night. -> None
# Mary -> This is Mary Jackson.
# It's Sunday Please, have some shame. -> None
# I will not. -> I will not.
# Mm. I think he's smiling over here. -> I think he’s smiling over here.
# At you -> At you.
# I'm not smiling back. -> I’m not smiling back.
# You're all teeth right now. -> You’re all teeth right now.
# I am not -> I am not.
# He's coming over -> He’s coming this way.
# Now, why would he be doing that? -> None
# Because Mary's waving at him -> Mary’s waving him over.
# No! Ladies, I'm not.. -> I’m Dorothy Vaughan.
# Too late. Fix your hair on the side. -> Too late.
# I'm Dorothy Vaughan. That's Mary Jackson. I believe you met her husband, Levi. -> I’m Dorothy Vaughan.
# Yes, ma'am. Good to meet you all. -> Yes, ma’am.
# And Ms. Katherine Goble. -> And this is Katherine Goble.
# She's not married. She's a widow. -> She’s not married.
# With three beautiful little girls, -> None
# so well-behaved. Angels on earth, is what we'd like to call 'em. -> Angels on earth, we call ‘em.
# Dorothy, slice-a pie? -> Dorothy, slice-a pie?
# I'd love one -> I’d love one.
# Excuse me -> None
# You already have a slice-a pie, Doro.. -> Dorothy, slice-a pie?
# Well, I was just -> Well.
# fixing my three babies some plates. -> None
# May I help? -> Mr. Johnson, it may be best if you quit talking right now.
# Sure. Ah! Fruit salad! -> None
# Pastor mentioned you're computer at NASA -> Pastor mentioned you’re a “Computer” at NASA.
# Yes -> None
# What's that entail? -> What’s that entail?
# We calculate the mathematics necessary to enable -> We calculate the mathematics necessary to enable launch and landing for the Space Program.
# launch and landing for the Space Program. -> We calculate the mathematics necessary to enable launch and landing for the Space Program.
# Pretty heady stuff! -> Pretty heady stuff.
# Yes, it is. -> So, yes...they let women do some things over at NASA, Mr. Johnson.
# They let women handle that sort of.. -> They let women handle that kind of-
# That's.. Not what I mean -> That’s not what I mean.
# What do you mean? -> What do you mean?
# I am.. Just surprised something so.. Taxing -> I was just surprised something so...taxing-
# Mr. Johnson -> So, yes...they let women do some things over at NASA, Mr. Johnson.
# If I were you, I'd quit talking right now -> None
# I don't mean any disrespect -> I’m not meaning any disrespect-
# I'll have you know, I was the first Negro female -> I’ll have you know, I was the first Negro female student at West Virginia University Graduate School.
# student at West Virginia University Graduate School. -> I’ll have you know, I was the first Negro female student at West Virginia University Graduate School.
# On any given day, I analyze the manometer levels -> On any given day I analyze the manometer levels for air displacement, friction and velocity and compute over 10,000 calculations by cosine, square root and lately Analytic Geometry.
# for air displacement friction and velocity. -> On any given day I analyze the manometer levels for air displacement, friction and velocity and compute over 10,000 calculations by cosine, square root and lately Analytic Geometry.
# And compute over 10,000 calculations by cosine, -> On any given day I analyze the manometer levels for air displacement, friction and velocity and compute over 10,000 calculations by cosine, square root and lately Analytic Geometry.
# square root and lately Analytic Geometry. -> On any given day I analyze the manometer levels for air displacement, friction and velocity and compute over 10,000 calculations by cosine, square root and lately Analytic Geometry.
# By hand. There are 20 bright, -> By hand.
# highly capable Negro women in the West Computing Group, -> There are 20 bright, highly capable Negro women in the West Computing Group.
# and we're proud to be doing our part for the country. -> And we’re proud to be doing our part for the country.
# So, yes -> None
# They let women do some things at NASA, Mr. Johnson. -> None
# And it's not because we wear skirts -> But it’s not because we wear skirts...it’s because we wear glasses.
# It's because we wear glasses -> But it’s not because we wear skirts...it’s because we wear glasses.
# Have a good day -> None
# Scott, welcome to Langley. Welcome to Langley. -> None
# Right here, Gentlemen -> Gentlemen, if we may...much to see around here.
# That's Alan Shepard. -> Alan Shepard.
# US Navy pilot. He could be the first man in space. -> US Navy pilot.
# That's Scott Carpenter and Walter Schirra. -> None
# Also Navy pilots. -> US Navy pilot.
# All under 5'11", 180 lbs. -> DOROTHY All under 5’11”, 180 lbs.
# IQs over 130. -> IQs over 130.
# And handsome must be a requirement too. -> Handsome must be a requirement too.
# How could you possibly be ogling these white men? -> How can you possibly be ogling these white men?
# It's equal rights. I have the right to see fine in every color. -> It’s equal rights.
# That's John Glenn. -> That’s John Glenn.
# He's the only Marine Corps pilot. -> The only Marine Corps pilot.
# Gentlemen, if we may.. Much to see around here. -> Gentlemen, if we may...much to see around here.
# We haven't shaken all the hands yet. -> Heck, haven’t shaken all the hands yet.
# We have a fairly tight itinerary, Colonel. -> We have a fairly tight itinerary, Colonel.
# Ruth, it's fine. -> I have the right to see fine in every color.
# He's coming straight. -> Look straight ahead.
# Look around ahead. -> Look straight ahead.
# Ladies. Didn't wanna run off without saying hello -> Didn’t wanna run off without saying hello.
# They seem to be in a big rush around here. -> They seem to be in a big rush around here.
# The Russians certainly aren't slowing down any. -> The Russians certainly aren’t slowing down any.
# They can't build the refrigerator, how the heck they beat us into space? -> They can’t make a damn ‘frigerator, how the heck they beat us into space?
# What do you ladies do for NASA? -> What do you gals do for NASA?
# Calculate your trajectories. Launch and landing. -> Launch and landing.
# I can't get anywhere without the numbers. -> Can’t get anywhere without the numbers.
# No, sir. -> No, sir.
# Mary Jackson, Mr. Glenn. -> Mary Jackson, Mr. Glenn.
# Engineering. And I'm proud as the devil to be workin' with you. -> Proud as the devil to be workin’ with you.
# Thank you, Mary. -> Thank you, Mary.
# John! -> None
# I must take it inside -> None
# Yes, sir. -> None
# Guys! -> None
# Mr. Harrison wants you to confirm launch -> Mr. Harrison wants you to confirm launch and landing for the Redstone Rocket test.
# and landing for the Redstone Rocket test. -> Mr. Harrison wants you to confirm launch and landing for the Redstone Rocket test.
# I cannot work on what I cannot see, Mr. Stafford. -> I cannot work on what I cannot see, Mr. Stafford.
# It's illegible. -> It’s illegible.
# Those numbers have already been confirmed by two engineers -> The numbers have been confirmed by two Engineers in this department, and myself.
# in this department, and myself. -> The numbers have been confirmed by two Engineers in this department, and myself.
# This is more or less a dummy check. -> It’s more-or less a dummy check.
# This one, like make a two. Make a double. OK? Get it? -> None
# No one thought to measure these things. -> No one thought to measure this thing.
# I'm afraid, not. Sir. -> I’m afraid not.
# Would you like us to stop? -> None
# No. No, just.. -> No, just keep going.
# I see, no. Just keep going. -> No, just keep going.
# In fact -> None
# Use.. Use the big hammer -> None
# Yes, sir. -> None
# Come on, use the big hammer. You heard the man. Let's go! -> None
# Ma'am. -> It’s break time, ma’am.
# ...
# I know, but he is.. You are, right? -> I know.
# If ya'll let me. -> If anyone will let me.
# Go on. She's already crying. -> She’s already crying.
# This was my mother's ring. -> This was my mother’s ring.
# It is beautiful -> None
# She and my father were married for.. -> She and my father were married-
# For 52 years. -> For 52 years.
# I figure it's about as lucky as a ring as you can get. -> I figure it’s about as lucky a ring as you can get.
# The day I met you, I called my mother... -> The day I met you, I called my mother and asked her if I could have it.
# I said: "Mom! I met the woman I want to marry." -> I said, “Mom, I met the woman I want to marry.”
# What'd she say? -> What’d she say?
# She said: "She must be something, Jimmy. Really something." -> She said, “She must be something, Jimmy.
# Then what'd you say? -> What’d she say?
# I said: "No, She is more than Something, She is Everything." -> None
# I planned on this being more romantic. I'll make that up to you real soon. -> I planned on this being more romantic.
# But I know marrying you.. Includes me and the girls as well. -> But I know marrying you...includes the girls as well.
# Amen to that. -> Amen to that.
# I do. -> I do.
# I didn't ask you yet. -> I didn’t ask you yet.
# Hurry up! -> None
# No pain, please! No, girls. No tears. -> None
# The Mercury Atlas Space vehicle, which will putt John Glenn -> None
# the first American into Earth orbit, -> None
# has already undergone 5 unmanned flight tests. -> None
# NASA has confirmed that the IBM 790 data processing -> None
# system has been utilized to confirm all of the mission's long and recovery system calculations. -> None
# The modifications and equipment installations are progressing on the schedule. -> None
# Them, Here -> None
# You wanted to see me, sir? -> You wanted to see me, sir?
# Have a seat -> Have a seat.
# Is there something wrong, Mr. Harrison? -> Something wrong, Mr. Harrison?
# No. There's nothing wrong. -> There’s nothing wrong.
# In fact our IBM is churning out numbers in fractions of the time any human can -> In fact our IBM is churning out numbers in fractions of the time any human can.
# Present company included. -> Present company included.
# That's good then. -> That’s good then.
# Maybe. -> Maybe.
# The thing is, the Cape is now insisting on doing all the backups down there. On site. -> The thing is, the Cape is now insisting on doing all the backups down there.
# I see. -> I see.
# So, we won't be running backups here. -> So, we won’t be running backups here.
# And truth be told, we can't keep up with that IBM anyhow. -> And truth be told, we can’t keep up with that IBM anyhow.
# Long story short, we no longer need a.. Computer in this department. -> Long story short, we no longer need a computer in this department.
# Progress is a double edged sword. -> Progress is a double edged sword.
# Let's have you report back to the West Group for now. -> Let’s have you report back to the West Group for now.
# I'll see if we can find another assignment. -> We’ll see if we can find another assignment.
# Thank you, sir. -> Thank you, sir.
# Katherine, I'm.. I'm sorry about this -> I’m sorry about this, Katherine.
# It's out of my hands, if you can believe that. -> It’s out of my hands, if you can believe it.
# I understand. -> I understand.
# Katherine.. We heard you got engaged. -> Heard you got engaged.
# Yes. That's thoughtful of you. -> That’s very thoughtful of you.
# They're lovely. -> They’re lovely.
# Mr. Harrison's idea really. -> Mr. Harrison’s idea really.
# Although I suspect his wife did the picking out. -> Although I suspect his wife did the picking out.
# I can't imagine he has an eye for anything but numbers.. -> I can’t imagine he has an eye for such things...
# Now, you have a great wedding. You did good work around here, Katherine. -> Now you have a great wedding.
# I don't think I felt a thing the first time I did this. -> I don’t think I could feel a thing the first time I did this.
# I was so nervous. -> None
# This is as beautiful as you were back then. -> You look even more beautiful than you did back then.
# You think so? -> You think so?
# Just a little older. -> Just a little older.
# And a little fuller... But you look good. -> And a little fuller.
# Here we go. Again. -> None
# That'a girl -> None
# .. And Colonel John Glenn will be the first American to orbit the Earth. -> #3 ...John Glenn, the first American to orbit the Earth.
# As you can see, there are thousands of people here to witness this historic event -> There are thousands of people here today...
# Paul, something's off here. These landing coordinates don't match yesterday's. -> These landing coordinates don’t match yesterday’s.
# The IBM just ran them. -> The IBM just ran them.
# So then the IBM was wrong yesterday, right? -> Then the IBM was wrong yesterday.
# Or the damn thing is wrong today. -> Or it’s wrong today.
# Paul, Am I right? -> None
# It appears so. -> None
# The IBM has been spot on up to this point, John. -> The IBM has been spot on up to this point, John, but we’ll run it again, see what it comes up with.
# But we'll run it again, to see what it comes up with. -> The IBM has been spot on up to this point, John, but we’ll run it again, see what it comes up with.
# I'll be honest with you, Al When I fly, I fly the machine, -> To be honest with you, Al...when I fly, I fly the machine and now I feel like the machines are flying me.
# Right now, it seems like this machine is flying me. -> To be honest with you, Al...when I fly, I fly the machine and now I feel like the machines are flying me.
# We're on the same page, John. Our guys are on it. -> We’re on the same page.
# Let's get the girl to check the numbers. -> Let’s get the girl to check the numbers.
# The girl? -> The girl?
# Yes, sir. -> Yes, sir.
# You mean Katherine? -> HARRISON Sam...go find Katherine.
# Yes, sir. The smart one. -> Yes, sir.
# If she says they're good, I'm ready to go. -> If she says they’re good, I’m ready to go.
# All right. We'll get into it. -> None
# Roger! -> None
# Sam! Go find Katherine Goble. -> HARRISON Sam...go find Katherine.
# She needs to verify Glenn's Go/No Go or we're staying on the ground. -> She needs to verify Glenn’s Go/No Go or we’re staying on the ground.
# Yes, sir. -> Yes, sir.
# I'm looking for Katherine Goble -> I’m looking for Katherine Goble?
# It's Katherine Johnson now. -> It’s Katherine Johnson now.
# They need you to verify these coordinates. -> They need you to verify these.
# All right. Give her some space to work. -> Alright, give her space.
# A truly historic day for America.. -> None
# The country has waited for several months, through many failed unmanned Atlas rocket tests -> None
# and 10 scheduled manned attempts, -> None
# which were canceled for various mechanical or system complications. -> None
# All the final tests and checks are being conducted, John Glenn is ready to board the Friendship 7. -> All the final tests and checks are being conducted.
# But today we remain truly optimistic -> None
# and it's a go day in all regards -> We can confirm the Go/No Go point for re-entry is 16.11984, -165.2356.
# the capsule is ready, the rocket itself is a OK, and the weather here at.. -> None
# Anything from Langley? -> This is Langley.
# Not yet. -> Not yet.
# We're being told the mission control at Nasa is conducting a final check -> None
# of the launch and recovery coordinates including the go/no-go calculations -> None
# so crucial to a safe and successful launch and recovery -> None
# After years of waiting, and months of delays, -> None
# col. Glen is finally ready for that space flight we've been waiting for with so much anticipation -> None
# We are still a go. -> Here you go.
# Yes, sir. -> None
# That's it. -> That’s right, Colonel.
# What the devil are you doing? Are you taking a break? -> What the devil are you doing?
# You have the time? -> Right on time.
# Sir. -> Sir, we’ve got Pad 14 at the Cape on the line.
# Pad 14. -> Sir, we’ve got Pad 14 at the Cape on the line.
# Katherine! -> Katherine.
# Come on -> None
# Sir, we've got Pad 14 on the box. -> Sir, we’ve got Pad 14 at the Cape on the line.
# Alright, let me in there. -> Let her work.
# This is Langley. We have the coordinates confirmed. -> We have the coordinates confirmed.
# Standby, Langley. -> Anything from Langley?
# We can confirm the Go/No Go point for re-entry is.. -> None
# 16.11984 degrees latitude -> Latitude -69.643667.
# 165.2356 degrees longitude. -> Recovery position- Longitude 21.347821.
# The launch window is a go. The landing coordinates match. -> The launch window is a go.
# That's very good news, Al. -> Good to hear that, Al.
# It's a little hard to trust something you can't look in the eyes. -> Hard to trust something you can’t look in the eyes.
# That's right, Colonel. Katherine did manage to calculate -> Katherine did manage to calculate a few decimal points further than that hunk of metal.
# a few decimal points further than that hunk of metal. -> Katherine did manage to calculate a few decimal points further than that hunk of metal.
# Well, I'll take every digit ya got. Be sure to thank her for me. -> I’ll take every digit ya got.
# Gentlemen! Let's launch this rocket. -> None
# Good luck, Friendship 7. -> Good luck, Friendship 7.
# God speed, Langley. -> God speed, Langley.
# Here at Cape Canaveral the countdown has resumed as Colonel John Glenn -> None
# is now aboard Friendship 7, high above the Atlas rocket on Pad 14. -> Good luck, Friendship 7.
# A height of over 93 feet .. -> None
# These pictures are from Cape Canaveral, Florida Deck entry is now moving back. -> None
# We're go for launch. -> Go for liftoff.
# The Mercury Spacecraft umbilical is out -> None
# T-10 seconds, and counting -> T-minus 10 seconds.
# 8.. 7.. 6.. 5.. -> None
# 4.. 3.. 2.. -> 3.
# 1.. Zero. Ignition. -> Ignition.
# It's getting bumpy along here. -> It’s getting bumpy along here.
# Roger that. You are in Max Q. -> Roger that.
# Roger that Capcom -> Roger that.
# Twenty seconds to SECO. -> Twenty seconds to SECO--
# The trajectory is still be "OK". -> None
# Go for SECO. -> Go for SECO.
# Zero G. And I feel fine. -> I feel fine.
# John Glenn reports everything looks good -> None
# Oh, that view is tremendous. -> Oh, that view is tremendous.
# Roger that, Friendship 7. -> Roger, that, Friendship 7.
# You are go for orbit. -> You are go for orbit.
# Thank you, Capcom! -> Thank you for the information, Mrs. Mitchell.
# All right. 10.5 hours to go. If we make 7 round trips. -> 10.5 hours to go.
# I could use a coffee. -> I need a coffee.
# Well, as we approach the end of day here on the Eastern seaboard.. -> None
# Colonel Glenn is just beginning his third orbit. -> None
# Three quarters of the way across the African continent. -> None
# We see he is currently over Zanzibar, which is the next tracking station coming up. -> None
# Thankfully the Friendship 7 capsule is.. -> Standby, Friendship 7.
# New assignment came down the pike. -> New assignment came down the pike.
# Always changing round here. It's hard to keep up. -> Hard to keep up.
# Seems like they're gonna need a permanent team to feed that IBM -> Seems like they’re gonna need a permanent team to feed that IBM.
# How big of a team? -> How big of a team?
# 30 to start. -> 30 to start.
# Thank you for the information, Mrs. Mitchell. -> Thank you for the information, Mrs. Mitchell.
# You're quite welcome... Mrs. Vaughan. -> You’re quite welcome...Mrs. Vaughan.
# We have a warning light! -> Capcom 7, I have a warning light.
# Capcom 7, I have a warning light. -> Capcom 7, I have a warning light.
# Standby, 7. -> If we make 7 round trips.
# Sir, we have a warning light! -> Capcom 7, I have a warning light.
# What are we looking at, Paul? -> What are we looking at, Stafford?
# The heat shield may have come loose. -> The heat shield may have come loose.
# 7, will you confirm the landing bag is in the OFF position? -> 7, will you confirm the landing bag is in the OFF position?
# Affirmative, Capcom. -> Affirmative, Capcom.
# Al, we need to get him down, now He could burn up on re-entry. -> We need to get him down, now.
# Come on, babies! -> The heat shield may have come loose.
# There's a man in space. We don't want to miss it, so we gonna home. -> There’s a man in space.
# Something's wrong with Glenn. -> Something’s wrong with Glenn.
# Oh, my Goodness! -> Oh, God.
# What's going on? -> You're going to use fly-by-wire for reentry.
# Let's go. -> I think the package just let go.
# Ya'll follow me. -> None
# We've just learned, the Friendship 7 is in danger of losing its heat shield. -> Friendship 7.
# Have you heard any banging noises? Or anything of this type at higher rates? -> None
# That's a negative, Capcom. -> Loud and clear, Capcom.
# Tell him not to jettison the retro-package. -> None
# Tell him not to jettison the retro-package. -> None
# NASA is confirming there is some sort of malfunction with the capsule's heat shield, -> None
# and it may not stay in place. -> None
# If the heat shield is loose... The retro- package straps might hold it in place. -> None
# Will that work? -> None
# It will work. -> None
# It will hold it until he reaches the Go /No Go point. It will work! -> None
# He has to override the 05g. -> None
# Do it. -> None
# Friendship 7... -> Friendship 7, do you copy?
# We're recommending that the retro-package NOT, I repeat, NOT be jettisoned. -> None
# This means that you will have to override the 05g switch. -> None
# Roger! Is there a reason for this? Over. -> Roger that.
# Standby, 7. -> Standby 7.
# Not at this time, 7. -> Friendship 7, we have you in our sights.
# Roger, that command. I will make a manual 05g entry, -> None
# and bring the scope in. Over. -> None
# He knows. -> None
# Without a heat shield, there's no way a Colonel Glenn -> None
# can get back through the Earth's atmosphere. -> None
# The heat is simply too overpowering. A malfunction in the automatic control system -> None
# is causing the spacecraft to yaw in a skid like fashion -> None
# thus putting the Friendship 7's re-entry point in jeopardy -> None
# even now, col. Glen is skidding towards the US -> None
# and he must begin the retro sequence -> None
# You're going to be using fly-by-wire for reentry. -> None
# You'll need to maintain a zero angle. Over. -> None
# Roger. I'm on fly-by-wire, back-it up with manual. Over. -> None
# Keep talking to him. -> None
# Roger. The weather in the recovery area: 3 foot waves, 10 miles visibility. -> None
# Capcom, you're going out -> How do I look, Capcom?
# He's crossing the communication black-out zone. -> None
# There's a real fireball outside, and it's getting a little hot here! -> But that was a real fireball, boy.
# Friendship 7. Do you copy? Over. -> Do you copy?
# Again. -> None
# Friendship 7. Do you copy? Over. -> Seven, do you copy?
# Friendship 7. Do you copy? Over. -> Seven, do you copy?
# Loud and clear, Capcom. -> Loud and clear, Capcom.
# Roger that. How are you doing? -> How are you doing?
# My condition is good. But that was a real fireball, boy -> My condition is good.
# Roger that. Let's get you all the way home. -> Roger that.
# Roger that. Here's hoping these landing coords still hold. -> Roger that.
# Approaching 16.11984. -> Approaching -165.23.
# Roger that! -> Roger that.
# Approaching -165.2356. In 3, 2, 1. -> In 3, 2, 1.
# Engaging chutes. -> Engaging chutes.
# Beautiful chutes. How we're lookin, Capcom? -> None
# Your Go/No Go is good. Landing coordinates are spot on, 7. -> Your Go/No Go is good.
# Roger that, Capcom. -> Roger that, Capcom.
# I've always wanted to swim in the Bahamas. Over. -> Always wanted to swim in the Bahamas.
# John Glenn has splashed-down, and is being recovered. -> John Glenn has splashed-down and is being recovered.
# John Glenn has splashed-down safely and is being recovered by USS Noa. -> John Glenn has splashed-down and is being recovered.
# Katherine! -> Nice work, Katherine.
# Nice work. -> Nice work, Katherine.
# You too, Mr. Harrison. -> You too, Mr. Harrison.
# So.. -> None
# You think we can get to the moon? -> You think we can get to the moon?
# We're already there, sir. -> We’re already there, sir.
# Girls..... This is Mrs. Vaughan. Your supervisor. -> This is Mrs. Vaughan.
# She'll show you how things work. -> She’ll show you how things work.
# Yeah! Come on in -> None

# %%
# Count how many nones and how many total subtitles were seen
none_count, total_count = 0,0
for match_idx, sub in labeled_subs:
    if match_idx is None:
        none_count += 1
    total_count += 1
print(none_count)
print(total_count)
# Out:
# 343
# 1653

# %%
original_labeled_subs = copy.deepcopy(labeled_subs)
rewrite_subtitles_with_characters(scply_chars, labeled_subs, subtitles_path, out_path)
labeled_subs = copy.deepcopy(original_labeled_subs)
